# %% [markdown]
# # Exportando .csv e criação de gráficos
# Breve caderno de anotações seguido de exercício prático

# %% [markdown]
# ### Foi tomado como base os seguintes tutoriais:
#
# https://www.youtube.com/watch?v=cd6eU5GV_8o - Como abrir arquivos no Python usando Pandas.
#
# https://www.youtube.com/watch?v=1-R5b3dTvhs - Como criar gráficos com Python usando Matplotlib.
#
# https://www.youtube.com/watch?v=iSpi3rKdoLQ - Gráficos em Python? - Análise de Dados.

# %% [markdown]
# ### Primeiro passo é sempre importar as bibliotecas necessárias para a execução da atividade.
#
# ### Neste caso, elas são: panda, numpy e matplotlib.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
csv1 = pd.read_csv ('/home/yuri/JUPYTER NOTEBOOK/athlete_events.csv')

# %%
csv1.head ()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
csv1.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# ### Segregando colunas

# %%
medalhas_ouro = csv1.loc[csv1 ['Medal'] == 'Gold']

# %%
medalhas_ouro
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
medalhas_prata = csv1.loc[csv1['Medal'] == 'Silver']

# %%
medalhas_prata
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 63          20                   Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 67          20                   Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 86          25                     Alf Lied Aanning   M  24.0     NaN     NaN
# 92          30                     Pepijn Aardewijn   M  26.0   189.0    72.0
# 106         38                         Karl Jan Aas   M  20.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 271013  135522      Klaas Erik "Klaas-Erik" Zwering   M  23.0   189.0    80.0
# 271015  135523       Ronald Ferdinand "Ron" Zwerver   M  25.0   200.0    93.0
# 271046  135544                   Krzysztof Zwoliski   M  21.0   175.0    70.0
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
medalhas_bronze = csv1.loc[csv1['Medal'] == 'Bronze']

# %%
medalhas_bronze
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 50          17              Paavo Johannes Aaltonen   M  32.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271032  135535            Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271048  135545                      Henk Jan Zwolle   M  27.0   197.0    93.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
#
# ...

# %% [markdown]
# ### Construindo gráficos (plots)

# %%
csv1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
y = csv1['Year']
a = csv1['Age']

# %%
plt.scatter(y,a)
